# %% [markdown]
# #### Exercise 1

# %% [markdown]
# In the code below, which will never print regardless of the value for x? Edit the code to correct the error.
#
# ```python
# if x > 0 :
#     print('Above 0')
# elif x >  10 :
#     print('Above 10')
# elif x > 50 :
#     print('Above 50')
# elif x >  20 :
#     print('Above 20')
# else :
#     print('Something else')
# ```

# %%
#The line elif x > 50 : print('Above 50'), elif x > 20 : print('Above 20), elif x > 10 ('Above 10) : print  will never print
# We should rearrange the conditions in descending order, starting with the highest value in order to run the code correctly

x = 200

if x > 50 :
    print('Above 50')
elif x > 20 :
    print('Above `20')
elif x > 10 :
    print('Above 10')
elif x >  0 :
    print('Above 0')
else :
    print('Something else')
# Out:
# Above 50

# %% [markdown]
# #### Exercise 2

# %%
hours = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))

if hours <= 40:
    pay = hours * rate
else:
    normal_pay = 40 * rate
    overtime_pay = (hours - 40) * rate * 1.5
    pay = normal_pay + overtime_pay

print("Pay:", pay)
# Out:
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0

# %% [markdown]
# Write your salary computation to give an employee 1.5 times the hourly rate for hours worked above 40 hours. Example:
#
#     Enter Hours: 45
#     Enter Rate: 10
#     Pay: 475.0
#
# [PEW] E3.2

# %% [markdown]
# ## CHALLENGE

# %%
score = float(input("Enter a score between 0 and 100: "))

if score >= 97:
    grade = 1.0
elif score >= 93:
    grade = 1.25
elif score >= 89:
    grade = 1.5
elif score >= 85:
    grade = 1.75
elif score >= 81:
    grade = 2.0
elif score >= 77:
    grade = 2.25
elif score >= 74:
    grade = 2.5
else:
    grade = 3.0

print("Grade:", grade)
# Out:
# Enter a score between 0 and 100: 101
# Grade: 1.0

# %% [markdown]
# Write a program to prompt for a score between 0 and 100 and print a grade using the following table:
#
#     Score           Grade
#     [ 97, 100]      1.0
#     [ 93,  97)		1.25
#     [ 89,  93)		1.5
#     [ 85,  89)		1.75
#     [ 81,  85)		2.0
#     [ 77,  81)		2.25
#     [ 74,  77)		2.5
#     [ 0,   74)		3.0
#
# Adapted from [PEW] E3.3
# <br>
