# %% [markdown]
# EXERCISE 1
#
#
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
print('Hello world!') # the letter P is in capital letter
# Out:
# Hello world!

# %%
print("Hello world!") # missing qoute after print
# Out:
# Hello world!

# %%
print("Hello world!") #  there a missing qoute at the end of !
# Out:
# Hello world!

# %%
print("Hello world!") # it should be a single or double qoute before and after the variable inside the parentheses
# Out:
# Hello world!

# %% [markdown]
# EXERCISE 2
#
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x)  # x= 44
# Out:
# 44

# %% [markdown]
# EXERCISE 3
#
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = x + 1 # the X variable is undefined
print(x)
# Out:
# 44
